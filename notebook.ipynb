# %%
import pandas as pd

df = pd.read_csv("./ml/data/retention_data.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# check how mean departements

departments = df["Department"]
departments.unique()

# select salary for department
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
# groupby
incomes = df["MonthlyIncome"]

df.groupBy("Department").mean("MonthlyIncome")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_138771/100171853.py in ?()
#       1 #groupby
#       2 incomes = df["MonthlyIncome"]
#       3
# ----> 4 df.groupBy("Department").mean("MonthlyIncome")
#
# ~/Desktop/project/simplon/retention-ai-hr/retention-ai-hr-assistant-API/venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'groupBy'
